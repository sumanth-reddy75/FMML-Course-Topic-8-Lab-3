# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanth-reddy75/FMML-Course-Topic-8-Lab-3/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-07 04:55:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   159MB/s    in 0.4s
#
# 2023-05-07 04:55:15 (159 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 38888   1212.3034v1  Ladars provide a unique capability for identif...    cs
# 2376    1210.4184v1  In this work, we propose the kernel Pitman-Yor...    cs
# 7546   1802.03050v1  In this paper we apply active learning algorit...  stat
# 22621  1703.01488v1  Topic models are one of the most popular metho...  stat
# 10790   1403.3707v1  From social networks to Internet applications,...    cs
# ...             ...                                                ...   ...
# 24110  1612.06129v1  The demands on visual recognition systems do n...    cs
# 37918   1111.1802v5  We develop a Bayesian nonparametric approach t...  stat
# 12397  1801.03533v1  Over the past two decades, the notion of impli...    cs
# 14251   1112.4258v5  This paper considers the problem of clustering...    cs
# 31439  1803.04022v1  Deep dictionary learning seeks multiple dictio...    cs
#
#                                                    title  year  \
# 38888             Multi-target tracking algorithms in 3D  2012
# 2376                       The Kernel Pitman-Yor Process  2012
# 7546               Thompson Sampling for Dynamic Pricing  2018
# 22621  Autoencoding Variational Inference For Topic M...  2017
# 10790  Learning the Latent State Space of Time-Varyin...  2014
# ...                                                  ...   ...
# 24110  Active and Continuous Exploration with Deep Ne...  2016
# 37918  Combinatorial clustering and the beta negative...  2011
# 12397  Selection Problems in the Presence of Implicit...  2018
# 14251  A geometric analysis of subspace clustering wi...  2011
# 31439  Deep Dictionary Learning: A PARametric NETwork...  2018
#
#                                                 keywords
# 38888  [capability, identification, describes, algori...
# 2376   [nonparametric, clustering, interdependencies,...
# 7546   [algorithms, prominent, decisions, approaches,...
# 22621  [representations, challenge, mathematically, i...
# 10790  [applications, electronic, communication, prod...
# ...                                                  ...
# 24110  [recognition, complexity, consequence, continu...
# 37918  [nonparametric, individuals, simultaneously, e...
# 12397  [important, component, understanding, discrimi...
# 14251  [considers, clustering, collection, unlabeled,...
# 31439  [dictionary, dictionaries, different, compleme...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 38888    [capability, identification, describes, algori...
# 2376     [nonparametric, clustering, interdependencies,...
# 7546     [algorithms, prominent, decisions, approaches,...
# 22621    [representations, challenge, mathematically, i...
# 10790    [applications, electronic, communication, prod...
#                                ...
# 5666     [representations, observations, factorization,...
# 2664     [challenging, structure, complicated, solution...
# 12126    [completion, reconstruct, structured, partiall...
# 22043    [observations, continuous, distribution, nonpa...
# 22227    [consequences, percentage, regression, equival...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8770 words.
# Out of those 4571 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4e45125b-3f0f-44b2-90d2-17f0c3762c10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e45125b-3f0f-44b2-90d2-17f0c3762c10")) {                    Plotly.newPlot(                        "4e45125b-3f0f-44b2-90d2-17f0c3762c10",                        [{"x":["including","connected","trajectories","selectable","describes","capability","identification","attributes","preprocessing","components","morphology","frameworks","speculate","algorithms","proximity","clustering","interdependencies","predictors","probability","predictor","hyperparameters","controlled","expressing","distributed","construction","constructed","nonparametric","considering","dependent","introducing","locations","parameters","prominent","decisions","approaches","underlying","algorithm","historical","efficiently","autoencoding","unnecessary","dirichlet","illustration","mathematically","inference","computational","representations","collapsed","knowledge","effective","optimization","challenge","collapsing","allocation","traditional","interpretable","component","promising","variational","transitions","probabilistic","structure","electronic","stationary","relationships","applications","producing","represent","characteristics","communication","framework","correspond","subsequences","mechanisms","increased","important","different","implement","supervised","attention","contributing","sentiment","contribute","activation","experimental","classification","correctly","represented","inclusion","information","methodology","convolutional","evaluated","identifying","mechanism","continuous","applicability","sentences","successfully","discriminating","identifies","corresponding","necessary","decomposes","architecture","validated","challenging","decompose","regularization","principled","accordingly","developed","scenarios","experiments","demonstrates","variations","variables","incorporate","generated","generalization","accounting","performance","recognition","instances","adaptively","temporally","investigates","performances","classifiers","structured","effectively","understanding","particular","activities","iteratively","discovers","segmented","techniques","considered","collecting","character","robustness","fingerprint","verification","conclusion","precision","respectively","authorship","unweighted","validation","attribution","interface","microsoft","productivity","harnessing","background","inferring","assistance","prototypes","reasoning","assistant","persistent","observational","developing","development","expertise","intelligent","transforming","unrelated","achieving","undesired","accumulation","illustrate","enforcement","diagnosis","virtually","generative","protected","additional","practically","internally","simultaneously","universally","guarantee","adversarial","automatically","similarly","companies","hospitals","contradicting","environment","exploitation","impossible","confronted","augmenting","baselines","dimensional","prognostic","overlooked","combining"],"y":[244,57,33,2,79,64,97,66,17,103,18,37,4,548,8,152,6,15,155,16,13,28,15,100,73,57,18,72,84,46,37,259,12,55,401,112,837,19,142,1,8,24,4,15,211,321,246,1,370,271,301,146,0,25,184,32,100,126,41,15,137,365,21,25,74,448,35,142,98,65,584,29,3,53,48,346,763,77,203,194,9,45,32,38,414,487,34,83,9,713,69,367,145,75,117,108,32,77,95,6,30,139,66,12,230,32,276,13,81,20,16,240,95,604,46,83,151,68,174,120,12,854,393,109,32,21,32,37,98,115,118,168,278,40,41,12,28,380,149,19,53,103,7,41,18,74,79,5,1,55,11,33,12,4,4,77,22,9,4,127,11,4,8,58,112,9,47,17,6,70,3,5,73,5,50,11,120,1,119,17,3,89,5,31,97,216,11,10,2,1,115,19,21,3,13,57,214,2,5,118],"type":"bar"},{"x":["including","connected","trajectories","selectable","describes","capability","identificati ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4571,), (4571, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Novel</span> <span style=''>Boundary</span> <span style=''>Matching</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Video</span> <span style=''>Temporal</span> <span style=''>Error</span> <span style=''>Concealment</span> <br/><br/><span style=''>With</span> <span style=''>the</span> <span style=''>fast</span> <span style=''>growth</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4942528735632184);'>communication</span> <span style=''>networks</span> <span style=''>the</span> <span style=''>video</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transmission</span> <span style=''>from</span> <span style=''>these</span> <span style=''>networks</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>vulnerable</span> <span style=''>Error</span> <span style=''>concealment</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>damaged</span> <span style=''>data</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>employing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correctly</span> <span style=''>received</span> <span style=''>data</span> <span style=''>at</span> <span style=''>the</span> <span style=''>decoder</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>boundary</span> <span style=''>matching</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3800000000000001);'>estimating</span> <span style=''>damaged</span> <span style=''>motion</span> <span style=''>vectors</span> <span style=''>(MVs)</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>performs</span> <span style=''>error</span> <span style=''>concealment</span> <span style=''>for</span> <span style=''>each</span> <span style=''>damaged</span> <span style=''>macro</span> <span style=''>block</span> <span style=''>(MB)</span> <span style='background-color:rgba(0, 255, 0, 0.48993288590604017);'>according</span> <span style=''>to</span> <span style=''>the</span> <span style=''>list</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identified</span> <span style=''>priority</span> <span style=''>of</span> <span style=''>each</span> <span style=''>frame</span> <span style=''>It</span> <span style=''>then</span> <span style=''>uses</span> <span style=''>a</span> <span style=''>classic</span> <span style=''>boundary</span> <span style=''>matching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>or</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>boundary</span> <span style=''>matching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adaptively</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>matching</span> <span style='background-color:rgba(0, 255, 0, 0.4814814814814815);'>distortion</span> <span style=''>in</span> <span style=''>each</span> <span style=''>boundary</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>candidate</span> <span style=''>MB</span> <span style=''>Finally</span> <span style=''>the</span> <span style='backg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Comunication</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communication</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>on</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>The</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>a</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>averaging</span> <span style=''>method</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributes</span> <span style=''>the</span> <span style=''>N</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>evenly</span> <span style=''>to</span> <span style=''>nummac</span> <span style=''>machines</span> <span style=''>performs</span> <span style=''>separate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>on</span> <span style=''>each</span> <span style=''>subset</span> <span style=''>and</span> <span style=''>then</span> <span style=''>averages</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>sharp</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>this</span> <span style=''>average</span> <span style=''>mixture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasonable</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>the</span> <span style=''>combined</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>achieves</span> <span style=''>mean</span> <span style=''>squared</span> <span style=''>error</span> <span style=''>that</span> <span style=''>decays</span> <span style=''>as</span> <span style=''>order(N</span> <span style=''>1(Nm)</span> <span style=''>2)</span> <span style=''>Whenever</span> <span style=''>m</span> <span style=''>le</span> <span style=''>sqrtN</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>matches</span> <span style=''>the</span> <span style=''>best</span> <span style=''>possible</span> <span style=''>rate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achievable</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>centralized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>having</span> <span style=''>access</span> <span style=''>to</span> <span style=''>all</span> <span style=''>totalnumobs</span> <span style=''>samples</span> <span style=''>The</span> <span style=''>second</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Supervised</span> <span style=''>Learning</span> <span style=''>II</span> <span style=''>Training</span> <span style=''>Margin</span> <span style=''>Based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifiers</span> <span style=''>without</span> <span style=''>Labels</span> <br/><br/><span style=''>Many</span> <span style=''>popular</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>such</span> <span style=''>as</span> <span style=''>logistic</span> <span style='background-color:rgba(255, 0, 0, 0.49044585987261147);'>regression</span> <span style=''>boosting</span> <span style=''>or</span> <span style=''>SVM</span> <span style=''>are</span> <span style=''>trained</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>a</span> <span style=''>margin</span> <span style=''>based</span> <span style=''>risk</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Traditionally</span> <span style=''>these</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>computed</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>labeled</span> <span style=''>dataset</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3800000000000001);'>estimating</span> <span style=''>such</span> <span style=''>risks</span> <span style=''>using</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style=''>marginal</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>estimator</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>on</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style=''>datasets</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>it</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>world</span> <span style=''>data</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style=''>estimate</span> <span style=''>is</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3924050632911392);'>evaluating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>in</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>for</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>with</span> <span style=''>no</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>whatsoever</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Landmark</span> <span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>Kernel</span> <span style=''>methods</span> <span style=''>obtain</span> <span style=''>superb</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>accuracy</span> <span style=''>for</span> <span style=''>various</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>since</span> <span style=''>they</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>extract</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>However</span> <span style=''>their</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>can</span> <span style=''>be</span> <span style=''>rather</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>define</span> <span style=''>a</span> <span style=''>general</span> <span style=''>class</span> <span style=''>of</span> <span style=''>kernels</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximated</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomization</span> <span style=''>These</span> <span style=''>kernels</span> <span style=''>appear</span> <span style=''>in</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>landmark</span> <span style=''>based</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>landmark</span> <span style=''>based</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>for</span> <span style=''>n</span> <span style=''>data</span> <span style=''>points</span> <span style=''>from</span> <span style=''>K</span> <span style=''>clusters</span> <span style=''>with</span> <span style=''>D</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>landmarks</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>results</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>O(KnD)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>bound</span> <span style=''>the</span> <span style=''>error</span> <span style=''>between</span> <span style=''>the</span> <span style=''>original</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>scheme</span> <span style=''>and</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.08892857142857143)
# 	representation (0.13035714285714287)
# 	segmentation (0.06964285714285715)
# 	experimental (0.14785714285714285)
# 	knowledge (0.13214285714285715)
# 	information (0.2546428571428571)
# 	detection (0.12428571428571429)
# 	convolutional (0.13107142857142856)
# 	recognition (0.14035714285714285)
# 	different (0.2725)
#
# Some Statistics words are:
# 	variational (0.0965)
# 	algorithm (0.3825)
# 	algorithms (0.287)
# 	distribution (0.1795)
# 	theoretical (0.155)
# 	estimation (0.1765)
# 	statistical (0.166)
# 	dimensional (0.1865)
# 	inference (0.203)
# 	regression (0.1755)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f00bb50c-58c6-4d65-a612-e8ab153f876f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f00bb50c-58c6-4d65-a612-e8ab153f876f")) {                    Plotly.newPlot(                        "f00bb50c-58c6-4d65-a612-e8ab153f876f",                        [{"x":["including","connected","trajectories","selectable","describes","capability","identification","attributes","preprocessing","components","morphology","frameworks","speculate","algorithms","proximity","clustering","interdependencies","predictors","probability","predictor","hyperparameters","controlled","expressing","distributed","construction","constructed","nonparametric","considering","dependent","introducing","locations","parameters","prominent","decisions","approaches","underlying","algorithm","historical","efficiently","autoencoding","unnecessary","dirichlet","illustration","mathematically","inference","computational","representations","collapsed","knowledge","effective","optimization","challenge","collapsing","allocation","traditional","interpretable","component","promising","variational","transitions","probabilistic","structure","electronic","stationary","relationships","applications","producing","represent","characteristics","communication","framework","correspond","subsequences","mechanisms","increased","important","different","implement","supervised","attention","contributing","sentiment","contribute","activation","experimental","classification","correctly","represented","inclusion","information","methodology","convolutional","evaluated","identifying","mechanism","continuous","applicability","sentences","successfully","discriminating","identifies","corresponding","necessary","decomposes","architecture","validated","challenging","decompose","regularization","principled","accordingly","developed","scenarios","experiments","demonstrates","variations","variables","incorporate","generated","generalization","accounting","performance","recognition","instances","adaptively","temporally","investigates","performances","classifiers","structured","effectively","understanding","particular","activities","iteratively","discovers","segmented","techniques","considered","collecting","character","robustness","fingerprint","verification","conclusion","precision","respectively","authorship","unweighted","validation","attribution","interface","microsoft","productivity","harnessing","background","inferring","assistance","prototypes","reasoning","assistant","persistent","observational","developing","development","expertise","intelligent","transforming","unrelated","achieving","undesired","accumulation","illustrate","enforcement","diagnosis","virtually","generative","protected","additional","practically","internally","simultaneously","universally","guarantee","adversarial","automatically","similarly","companies","hospitals","contradicting","environment","exploitation","impossible","confronted","augmenting","baselines","dimensional","prognostic","overlooked","combining","healthcare","instability","significant","improvement","correlations","detecting","technique","autoencoder","consistency","correlation","stability","estimation","stabilizing","demonstrated","stabilization","conducted","unlabelled","prediction","processor","therefore","uncoupled","benchmark","generation","processing","nonlinear","significantly","questions","reservoir","computers","implementations","introduce","investigations","remarkable","computing","simplicity","possibility","potentially","forecasting","demonstrate","numerical","emulation","processed","supervision","appearance","independently","evaluation","interaction","configuration","experiences","successful","autonomous","perceivable","reinforcement","acceptable","recurrent","sele ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	collapsing
# 	likelihoods
# 	graphically
# 	linearized
# 	inverting
# 	validator
# 	periodicity
# 	dependences
# 	regressions
# 	parametrizations
# 	embarrassingly
# 	hippocampus
# 	psychiatric
# 	binarycategorical
# 	diarization
# 	parametrically
# 	cheminformatics
# 	seasonality
# 	quantiles
# 	minimisation
# Some words which never appear in Statistics papers:
# 	selectable
# 	speculate
# 	assistance
# 	assistant
# 	processor
# 	perceivable
# 	deceptive
# 	incredible
# 	inseparable
# 	paralleling
# 	evidential
# 	prioritizes
# 	personalize
# 	hypertension
# 	subclasses
# 	decidability
# 	worldwide
# 	transcribed
# 	deductive
# 	subproblem

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.070215836173283e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
